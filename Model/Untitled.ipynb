# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
Data = pd.read_csv("MalwareData.csv",sep='|')
Data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 Data = pd.read_csv("MalwareData.csv",sep='|')
#       2 Data.head()
#
# NameError: name 'pd' is not defined

# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.Installing collected packages: tzdata, pytz, pandas
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2021.5
#     Uninstalling tzdata-2021.5:
#       Successfully uninstalled tzdata-2021.5
# ...
# WARNING: You are using pip version 21.3.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\Manish\.conda\envs\testenv\python.exe -m pip install --upgrade pip' command.
