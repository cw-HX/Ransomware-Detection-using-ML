# %%
import pandas 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,accuracy_score,auc,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
data  = pandas.read_csv("data_ransomware.csv")

# %%
data
# Out:
#                                           FileName  \
# 0      VirusShare_0a09a21c2f28c8c5b5d168feb668a80b
# 1      VirusShare_bc4ce1d0466f42493418d65b9a1e880f
# 2      VirusShare_3086d1682a10bca61945ccca93cc8098
# 3      VirusShare_0683b586f3b9ea7a06d4d31555f31f80
# 4      VirusShare_d74daee515bd5a77f299151a568cb57a
# ...                                            ...
# 35362  VirusShare_a43ceb5e5fffc793e0205d15a0606cb0
# 35363  VirusShare_0190dafc8304111a00fccf57340ea6a4
# 35364  VirusShare_0f3ca55979aaf59158d6b01140696e44
# 35365  VirusShare_fca5ce35f1690db6babca5aa5d559535
# 35366  VirusShare_d7955a7e6d1e16800feafd4204cbac2b
#
#                                 md5Hash  Machine  DebugSize  DebugRVA  \
# 0      0a09a21c2f28c8c5b5d168feb668a80b      332          0         0
# 1      bc4ce1d0466f42493418d65b9a1e880f      332          0         0
# 2      3086d1682a10bca61945ccca93cc8098      332          0         0
# 3      0683b586f3b9ea7a06d4d31555f31f80      332          0         0
# 4      d74daee515bd5a77f299151a568cb57a      332         28     12336
# ...                                 ...      ...        ...       ...
# 35362  a43ceb5e5fffc793e0205d15a0606cb0      332          0         0
# 35363  0190dafc8304111a00fccf57340ea6a4      332          0         0
# 35364  0f3ca55979aaf59158d6b01140696e44      332          0         0
# 35365  fca5ce35f1690db6babca5aa5d559535      332          0         0
# 35366  d7955a7e6d1e16800feafd4204cbac2b      332          0         0
#
#        MajorImageVersion  MajorOSVersion  ExportRVA  ExportSize  IatVRA  \
# 0                      0               4          0           0    8520
# 1                      8              10     369716         160       0
# 2                      0               4          0           0     257
# 3                      0               5          0           0  245760
# 4                      0               4          0           0   28672
# ...                  ...             ...        ...         ...     ...
# 35362                  1               4          0           0    4096
# 35363                  7              10          0           0       0
# 35364                  0               4          0           0  404908
# 35365                  0               4      14448          70    4096
# 35366                  0               5          0           0    4096
#
#        MajorLinkerVersion  MinorLinkerVersion  NumberOfSections  \
# 0                       6                   0                 2
# 1                       9                   0                 3
# 2                       2                  50                 5
# 3                       9                   0                 7
# 4                       9                   0                 8
# ...                   ...                 ...               ...
# 35362                   6                   0                 3
# 35363                   7                   0                 7
# 35364                   2                  50                11
# 35365                   8                   0                 4
# 35366                   9                   0                 6
#
#        SizeOfStackReserve  DllCharacteristics  ResourceSize  BitcoinAddresses  \
# 0                 1048576                   0             0                 0
# 1                       0                   0           764                 0
# 2                 1048576                   0        227484                 0
# 3                 1048576               32768         45920                 0
# 4                 1048576                   0         96304                 0
# ...                   ...                 ...           ...               ...
# 35362             1048576                   0         23504                 0
# 35363             1048576                   0         15704                 0
# 35364             1048576                   0          2364                 0
# 35365             1048576                   0        130296                 0
# 35366             1048576                   0          6912                 0
#
#        Benign
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 35362       0
# 35363       0
# 35364       0
# 35365       0
# 35366       0
#
# [35367 rows x 18 columns]

# %%
data_new = data.loc[:,(data != 0).any(axis = 0)]
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35367 entries, 0 to 35366
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FileName            35367 non-null  object
#  1   md5Hash             35367 non-null  object
#  2   Machine             35367 non-null  int64
#  3   DebugSize           35367 non-null  int64
#  4   DebugRVA            35367 non-null  int64
#  5   MajorImageVersion   35367 non-null  int64
#  6   MajorOSVersion      35367 non-null  int64
#  7   ExportRVA           35367 non-null  int64
#  8   ExportSize          35367 non-null  int64
#  9   IatVRA              35367 non-null  int64
#  10  MajorLinkerVersion  35367 non-null  int64
#  11  MinorLinkerVersion  35367 non-null  int64
#  12  NumberOfSections    35367 non-null  int64
#  13  SizeOfStackReserve  35367 non-null  int64
#  14  DllCharacteristics  35367 non-null  int64
#  15  ResourceSize        35367 non-null  int64
#  16  BitcoinAddresses    35367 non-null  int64
# dtypes: int64(15), object(2)
# memory usage: 4.6+ MB

# %%
x = data_new.iloc[:,:-1].values
y = data_new.iloc[:,-1].values

# %%
print(x.shape)
# Out:
# (35367, 16)

# %%
print(y.shape)
# Out:
# (35367,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1, random_state = 0)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (31830, 16)
# (31830,)
# (3537, 16)
# (3537,)

# %%
x = data_new.iloc[:,2:-1]
x
# Out:
#        Machine  DebugSize  DebugRVA  MajorImageVersion  MajorOSVersion  \
# 0          332          0         0                  0               4
# 1          332          0         0                  8              10
# 2          332          0         0                  0               4
# 3          332          0         0                  0               5
# 4          332         28     12336                  0               4
# ...        ...        ...       ...                ...             ...
# 35362      332          0         0                  1               4
# 35363      332          0         0                  7              10
# 35364      332          0         0                  0               4
# 35365      332          0         0                  0               4
# 35366      332          0         0                  0               5
#
#        ExportRVA  ExportSize  IatVRA  MajorLinkerVersion  MinorLinkerVersion  \
# 0              0           0    8520                   6                   0
# 1         369716         160       0                   9                   0
# 2              0           0     257                   2                  50
# 3              0           0  245760                   9                   0
# 4              0           0   28672                   9                   0
# ...          ...         ...     ...                 ...                 ...
# 35362          0           0    4096                   6                   0
# 35363          0           0       0                   7                   0
# 35364          0           0  404908                   2                  50
# 35365      14448          70    4096                   8                   0
# 35366          0           0    4096                   9                   0
#
#        NumberOfSections  SizeOfStackReserve  DllCharacteristics  ResourceSize
# 0                     2             1048576                   0             0
# 1                     3                   0                   0           764
# 2                     5             1048576                   0        227484
# 3                     7             1048576               32768         45920
# 4                     8             1048576                   0         96304
# ...                 ...                 ...                 ...           ...
# 35362                 3             1048576                   0         23504
# 35363                 7             1048576                   0         15704
# 35364                11             1048576                   0          2364
# 35365                 4             1048576                   0        130296
# 35366                 6             1048576                   0          6912
#
# [35367 rows x 14 columns]

# %%
sns.countplot(data = data,x="Benign")
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.heatmap(data.corr(),annot = True, cmap='ocean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 plt.figure(figsize = (12,8))
# ----> 2 sns.heatmap(data.corr(),annot = True,cmap='ocean')
#
# File D:\Anaconda\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\Anaconda\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File D:\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File D:\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'VirusShare_0a09a21c2f28c8c5b5d168feb668a80b'

# %%
x = data_new.iloc[:, 2:-1].values
y = data_new.iloc[:,-1].values

# %%
x
# Out:
# array([[    332,       0,       0, ..., 1048576,       0,       0],
#        [    332,       0,       0, ...,       0,       0,     764],
#        [    332,       0,       0, ..., 1048576,       0,  227484],
#        ...,
#        [    332,       0,       0, ..., 1048576,       0,    2364],
#        [    332,       0,       0, ..., 1048576,       0,  130296],
#        [    332,       0,       0, ..., 1048576,       0,    6912]],
#       dtype=int64)

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
classifier = RandomForestClassifier(max_depth = 2,random_state = 0)
model = classifier.fit(x_train,y_train)

# %%
prediction = model.predict(x_test)
accuracy_score(y_test,prediction)*100
# Out:
# 98.87852228819149

# %%
plt.show(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.show(prediction)
#
# File D:\Anaconda\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
matrix = confusion_matrix(y_test,prediction)
sns.heatmap(matrix,annot=True)
# Out:
# <Axes: >

# %%
print("False positives:",matrix[0][1]/sum(matrix[0]*100))
print("False negatives:",matrix[1][0]/sum(matrix[1]*100))
